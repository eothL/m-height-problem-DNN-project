# %%
# !pip install tamu_csce_636_project1
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\theo-\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\theo-\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\theo-\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\theo-\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# ...

# %%
from tamu_csce_636_project1 import Evaluator
evaluator = Evaluator(
    first_name="Theo",
    last_name="Lin",
    email="theo.lin@tamu.edu",
    print=True,
)

# %%
### REPLACE ME: start ###
import torch
import torch.nn as nn

class WhateverModelYouLike(nn.Module):
    def __init__(self, n, k,):
        super(WhateverModelYouLike, self).__init__()
        input_size = ((n-2) * k)+1 # matrix size +1 for the m input
        print("input_size",input_size)
        self.fc1 = nn.Linear(input_size, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)

    def forward(self, m, matrix):
        # you probably don't want to Flatten, this is just a demo
        matrix_flat = matrix.view(matrix.size(0), -1)
        matrix_flat = matrix_flat
        x = torch.cat([m, matrix_flat], dim=1).to(torch.float32)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

def YOUR_FUNC_HERE(n, k, m, p_list):
    """
    Parameters:
        n (int)
        k (int)
        m (int)
        p_list (list): a list of P matrices, each matrix will be a numpy array

    Returns:
        a list of scalars, e.g. the m-height value, one for each matrix
    """
    model = WhateverModelYouLike(n, k)

    # ex: batch inputs
    integers = torch.tensor([[m] for each in p_list], dtype=torch.double)
    matricies = torch.tensor(p_list, dtype=torch.double)

    output = model(integers, torch.tensor(p_list))
    return output.flatten().tolist()
### REPLACE ME: end ###
# note: you can use as many cells as you like, don't feel limited to this cell

# %%
#     we will grade the code by running the following function
#     (note: when you run this it merely tests against 1 example value)
#     (when we run it, it will test against the full/hidden test set)
sigma = evaluator.eval(
    func=YOUR_FUNC_HERE,
)
dict(sigma)
# Out:
# input_size 7
# C:\Users\theo-\AppData\Local\Temp\ipykernel_31352\1752058862.py:39: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:257.)
#   matricies = torch.tensor(p_list, dtype=torch.double)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       1 #     we will grade the code by running the following function
#       2 #     (note: when you run this it merely tests against 1 example value)
#       3 #     (when we run it, it will test against the full/hidden test set)
# ----> 4 sigma = evaluator.eval(
#       5     func=YOUR_FUNC_HERE,
#       6 )
#       7 dict(sigma)
#
# ...

# %%
# OPTIONAL:
# you can more accurately simulate our grading
# by providing your own inputs/outputs
import numpy
sigma = evaluator.eval(
    inputs={
        # n,k,m
        '[5,2,2]': [
            # P matrix #1
            numpy.array([
                [ 0.4759809,  0.9938236, 0.819425 ],
                [-0.8960798, -0.7442706, 0.3345122],
            ]),
            # ... (additional P matrices here)...
        ],
    },
    outputs={
        '[5,2,2]': [
            1.9242387 # correct output for second P matrix
        ]
    },
    func=YOUR_FUNC_HERE,
)
# Out:
# input_size 7
# σ = {
#     # n, k, m
#     (5, 2, 2): 16.750656593818604,
# }
